# %%
# IMPORTS

import json
import math

import numpy as np
# import pandas as pd


#####
# import weigthed ranking coeff
import sys
project_paths = ["./ranking_correlation"]
for project_path in project_paths:
    if not (project_path in sys.path):
        sys.path.append(project_path)


from WA_params import metrics_of_interests
from WA_utils import corr_matrices_calculator
from plot_utils import read_data, plotter

# %% [markdown]
# # Churn Prediction - Extreme

# %% [markdown]
# ## Standard Spearman Coefficient

# %%
# # Calculate the results and write them in results folder

# metric_data_avg, metric_data_std = corr_matrices_calculator(weight=False, use_case='churn_extreme')
# Out:
# frac_plus=0.99, C_frac=0.99

# %%
from plot_utils import read_data, plotter_churn_extreme
metric_data_avg, metric_data_std = read_data(weight=False, use_case='churn_extreme')
metric_data_avg = {eval(k):v for k,v in metric_data_avg.items()}

plotter_churn_extreme(metric_data_avg)

# %%
metric_data_avg, metric_data_std = read_data(weight=False, use_case='churn_extreme')

print('\n\t Standard Spearman')
plotter(metric_data_avg)
# Out:
# 	 Standard Spearman

# %% [markdown]
# ## Weighted Spearman Coefficient

# %%
# Calculate the results and write them in results folder

metric_data_avg, metric_data_std = corr_matrices_calculator(weight=True, use_case='churn_extreme')
# Out:
# frac_plus=0.99, C_frac=0.99

# %%
metric_data_avg, metric_data_std = read_data(weight=True, use_case='churn_extreme')

print('\n\t Weighted Spearman')
plotter(metric_data_avg)
# Out:
# 	 Weighted Spearman

# %% [markdown]
# # Churn Extreme 2

# %% [markdown]
# ## Standard Spearman coefficient

# %%
# Calculate the results and write them in results folder

metric_data_avg, metric_data_std = corr_matrices_calculator(weight=False, use_case='churn_extreme_2')
# Out:
# frac_plus=0.99, C_frac=0.99

# %%
metric_data_avg, metric_data_std = read_data(weight=False, use_case='churn_extreme_2')

print('\n\t Standard Spearman')
plotter(metric_data_avg)
# Out:
# 	 Standard Spearman

# %% [markdown]
# ## Weighted Spearman Coefficient

# %%
# Calculate the results and write them in results folder

metric_data_avg, metric_data_std = corr_matrices_calculator(weight=True, use_case='churn_extreme_2')
# Out:
# frac_plus=0.99, C_frac=0.99

# %%
metric_data_avg, metric_data_std = read_data(weight=True, use_case='churn_extreme_2')

print('\n\t Weighted Spearman')
plotter(metric_data_avg)
# Out:
# 	 Weighted Spearman

# %% [markdown]
# # Credit Scoring

# %% [markdown]
# ## Standard Spearman Coefficient

# %%
# # Calculate the results and write them in results folder

# metric_data_avg, metric_data_std = corr_matrices_calculator(weight=False, use_case='credit')

# %%
metric_data_avg, metric_data_std = read_data(weight=False, use_case='credit')

print('\n\t Standard Spearman')
plotter(metric_data_avg)
# Out:
# 	 Standard Spearman

# %% [markdown]
# ## Weighted Spearman Coefficient

# %%
# Calculate the results and write them in results folder

metric_data_avg, metric_data_std = corr_matrices_calculator(weight=True, use_case='credit')
# Out:
# frac_plus=0.99, C_frac=0.99

# %%
metric_data_avg, metric_data_std = read_data(weight=True, use_case='credit')

print('\n\t Weighted Spearman')
plotter(metric_data_avg)
# Out:
# 	 Weighted Spearman

# %% [markdown]
# # Churn prediction

# %% [markdown]
# ## Standard Spearman Coefficient

# %%
# Calculate the results and write them in results folder

metric_data_avg, metric_data_std = corr_matrices_calculator(weight=False, use_case='churn')
# Out:
# frac_plus=0.99, C_frac=0.99

# %%
metric_data_avg, metric_data_std = read_data(weight=False, use_case='churn')

print('\n\t Standard Spearman')
plotter(metric_data_avg)
# Out:
# 	 Standard Spearman

# %% [markdown]
# ## Weighted Spearman Coefficient

# %%
# Calculate the results and write them in results folder

metric_data_avg, metric_data_std = corr_matrices_calculator(weight=True, use_case='churn')
# Out:
# frac_plus=0.99, C_frac=0.99

# %%
metric_data_avg, metric_data_std = read_data(weight=True, use_case='churn')

print('\n\t Weighted Spearman')
plotter(metric_data_avg)
# Out:
# 	 Weighted Spearman
